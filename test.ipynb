# %%
import os
import requests
from tqdm.notebook import tqdm

# Base URL for the FastAPI server
BASE_URL = "http://127.0.0.1:8000"

# Folder with images to upload for testing
TEST_FOLDER = "test"

# %%
# Add each image in the 'test' folder to the /add_face/ endpoint with a sample event name
def add_images(event_name):
    print("Adding images to the database...")
    for filename in tqdm(os.listdir(TEST_FOLDER)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            file_path = os.path.join(TEST_FOLDER, filename)
            with open(file_path, "rb") as file:
                response = requests.post(
                    f"{BASE_URL}/add_face/",
                    files={"file": file},
                    data={"event_name": event_name}
                )
                print(f"Response for {filename}:", response.json())

# %%
event_name = "Test Event"

    # Step 1: Add images to the database
add_images(event_name)
# Out:
# Adding images to the database...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 event_name = "Test Event"
#       3     # Step 1: Add images to the database
# ----> 4 add_images(event_name)
#
# Cell In[2], line 4, in add_images(event_name)
#       2 def add_images(event_name):
#       3     print("Adding images to the database...")
# ----> 4     for filename in tqdm(os.listdir(TEST_FOLDER)):
#       5         if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
#       6             file_path = os.path.join(TEST_FOLDER, filename)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tqdm\notebook.py:234, in tqdm_notebook.__init__(self, *args, **kwargs)
#     232 unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     233 total = self.total * unit_scale if self.total else self.total
# --> 234 self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     235 self.container.pbar = proxy(self)
#     236 self.displayed = False
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tqdm\notebook.py:108, in tqdm_notebook.status_printer(_, total, desc, ncols)
#      99 # Fallback to text bar if there's no total
#     100 # DEPRECATED: replaced with an 'info' style bar
#     101 # if not total:
#    (...)
#     105
#     106 # Prepare IPython progress bar
#     107 if IProgress is None:  # #187 #451 #558 #872
# --> 108     raise ImportError(WARN_NOIPYW)
#     109 if total:
#     110     pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
# List all unique events in the database
def list_events():
    print("\nListing all unique events in the database...")
    response = requests.get(f"{BASE_URL}/list_events/")
    print("Events:", response.json())

# Get all images associated with a specific event name
def get_images_by_event(event_name):
    print(f"\nGetting images for event: {event_name}...")
    response = requests.get(f"{BASE_URL}/get_images_by_event/", params={"event_name": event_name})
    print("Images for event:", response.json())

# Perform a face search on a specified image with an event name filter
def search_faces(event_name, search_image):
    print(f"\nSearching for faces in image: {search_image} for event: {event_name}...")
    with open(search_image, "rb") as file:
        response = requests.post(
            f"{BASE_URL}/search_faces/",
            files={"file": file},
            data={"event_name": event_name}
        )
    print("Search result:", response.json())

# Main function to run all tests
def main():
    # Step 2: List all unique events
    list_events()

    # Step 3: Get images by specific event
    get_images_by_event(event_name)

    # Step 4: Perform face search
    search_image_path = "Bhajan_Lal_Sharma.jpg"  # Replace with actual image path
    if os.path.exists(search_image_path):
        search_faces(event_name, search_image_path)
    else:
        print("Search image not found in the test folder!")

# Run the script
if __name__ == "__main__":
    main()
# Out:
# Listing all unique events in the database...
# Events: {'events': ['Test Event']}
#
# Getting images for event: Test Event...
# Images for event: {'matched_images': ['/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3782.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3785.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3785.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3785.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3785.JPG', '/teamspace/studios/this_studio/uploaded ...
#
# Searching for faces in image: Bhajan_Lal_Sharma.jpg for event: Test Event...
# Search result: {'matched_images': ['/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3900.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3916.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3806.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3888.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3796.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3861.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3800.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3801.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3802.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3899.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_4002.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3751.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_4012.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3815.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3977.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3889.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3907.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3949.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3998.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3792.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3828.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3849.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3960.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3962.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_4058.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3829.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3905.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3914.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3989.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3898.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3858.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3873.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_4029.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3753.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3872.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3904.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_4003.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3948.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3785.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3972.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3928.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_4006.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3793.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3797.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3848.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3859.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_4049.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3803.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3816.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3976.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3966.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3961.JPG', '/teamspace/studios/this_studio/uploaded_images/Test Event/CAM_3917.JPG', '/teamspace/studios/this_studio/uploaded_im ...
